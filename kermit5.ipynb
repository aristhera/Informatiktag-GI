# %%
import csv
import re
new = []
with open("5-ges.csv", "r") as f:
    reader = csv.reader(f)
    header = f.readline() # strip header
    print(reader)
    for i in reader:
        #print(i[0].split(';'))
        #new.append(i[0].split(';'))
    print(new)
# Out:
# ...
# ['Bastian', 'Jonas Carl Alexander', '30.10.2011', '5a']
# ['Braunwarth', 'Anna Charlotte Johanne', '28.05.2012', '5a']
# ['Correia Viegas', 'Noah Octavio', '08.08.2011', '5a']
# ['Daniel', 'Pauline Wilhelmine', '23.03.2012', '5a']
# ['Dold', 'Hannes', '14.05.2012', '5a']
# ['Eckhardt', 'Maja', '18.09.2011', '5a']
# ['Emetumah', 'Hafiza Uchechi', '19.06.2012', '5a']
# ['Fuhrmann', 'Laurenz Theodor', '05.05.2012', '5a']
# ['Gehring', 'Nora', '22.11.2011', '5a']
# ['Gjoka', 'Samuel', '05.12.2011', '5a']
# ['Gruhn', 'Levin', '19.11.2011', '5a']
# ['Jellema', 'Johann Cornelis', '04.01.2012', '5a']
# ['Mogensen', 'Laura-Marie', '02.08.2011', '5a']
# ['Nasseri', 'Leyla', '07.01.2012', '5a']
# ['Obtulowicz', 'Marta', '09.10.2011', '5a']
# ['Okhovatkhou', 'Kiarash', '17.10.2011', '5a']
# ['Omar', 'Adem', '23.11.2011', '5a']
# ['Orozco Pechinaki', 'Luca', '01.03.2012', '5a']
# ['Özcan', 'Nil Su', '16.12.2011', '5a']
# ['Panhoff', 'Eyk', '09.01.2011', '5a']
# ...

# %%
for i in new:
    #print(i[1])
    valid = re.search('([A-Za-z]+)([ ]?)(.+$)?', i[1])
    print(valid.group(1), end = ' ')
#print(new)
# Out:
# Jonas Anna Noah Pauline Hannes Maja Hafiza Laurenz Nora Samuel Levin Johann Laura Leyla Marta Kiarash Adem Luca Nil Eyk Carla Maya Felix Arne Maya Tiago Mathis Ida Klara Marisa Kelsey Nikolas Thilo Julyen Damien Clara Jana Emilia Neo Noah Leonie Carl L Diego Nils Alexander Christoph Paul Maja Fabio Sumaia Selina Lennart Hamza Amelia Daniel Dzhelen Nelis Marlon Nayeli Flora Mia Elyas Artemiy Laura Leon Joksim Eva Glenn Timofey Isabel Ishmeet Fynn Milan Jola Fabian Ramy Yannick Wim Talitha Noah Karla Robin Leni Ishaan Eva Isabella Ardian Merle David Merle Mia Jarik Ben Katharina Said Zlata Mara Elizabeth Leo Zoe

# %%
for i in range(len(new)):
    #print(new[i][1])
    valid = re.search('([A-Za-z]+)([ ]?)(.+$)?', new[i][1])
    new[i][1] = valid.group(1)
print(new)
# Out:
# [['Bastian', 'Jonas', '30.10.2011', '5a'], ['Braunwarth', 'Anna', '28.05.2012', '5a'], ['Correia Viegas', 'Noah', '08.08.2011', '5a'], ['Daniel', 'Pauline', '23.03.2012', '5a'], ['Dold', 'Hannes', '14.05.2012', '5a'], ['Eckhardt', 'Maja', '18.09.2011', '5a'], ['Emetumah', 'Hafiza', '19.06.2012', '5a'], ['Fuhrmann', 'Laurenz', '05.05.2012', '5a'], ['Gehring', 'Nora', '22.11.2011', '5a'], ['Gjoka', 'Samuel', '05.12.2011', '5a'], ['Gruhn', 'Levin', '19.11.2011', '5a'], ['Jellema', 'Johann', '04.01.2012', '5a'], ['Mogensen', 'Laura', '02.08.2011', '5a'], ['Nasseri', 'Leyla', '07.01.2012', '5a'], ['Obtulowicz', 'Marta', '09.10.2011', '5a'], ['Okhovatkhou', 'Kiarash', '17.10.2011', '5a'], ['Omar', 'Adem', '23.11.2011', '5a'], ['Orozco Pechinaki', 'Luca', '01.03.2012', '5a'], ['Özcan', 'Nil', '16.12.2011', '5a'], ['Panhoff', 'Eyk', '09.01.2011', '5a'], ['Schäfer', 'Carla', '25.03.2012', '5a'], ['Seemann', 'Maya', '20.05.2012', '5a'], ['Smarsly', 'Felix', '09.02.2012', '5a'], ['Stöver', 'Arn
# ...

# %%
for i in new:
    print(i[1][0] + i[1][-1].upper() + i[0][-1].upper() + i[2][0] + i[2][1]+i[2][3]+i[2][4])
# Out:
# JSN3010
# AAH2805
# NHS0808
# PEL2303
# HSD1405
# MAT1809
# HAH1906
# LZN0505
# NAG2211
# SLA0512
# LNN1911
# JNA0401
# LAN0208
# LAI0701
# MAZ0910
# KHU1710
# AMR2311
# LAI0103
# NLN1612
# EKF0901
# CAR2503
# MAN2005
# FXY0902
# AER2004
# MAI1409
# TOS0210
# MSE1004
# IAN0412
# KAN3012
# MAE0303
# KYI0912
# NSR2702
# TOG2505
# JNH2402
# DNT2208
# CAG1607
# JAS0408
# EAL3112
# NOSS2808
# NHSS2808
# LEX1001
# CLR1212
# LLS1505
# DOS0807
# NSR2011
# ARR2304
# CHZ2208
# PLE2501
# MAI2504
# FOR2207
# SAI1703
# SAF2901
# LTR1505
# HAA0408
# AAK1804
# DLC1306
# DNA0503
# NSA0503
# MNT1710
# NIE1408
# FAS2105
# MAS2602
# ESA0512
# AYO2607
# LAW1710
# LNX1001
# JMC0409
# EAR0902
# GNH1611
# TYW2609
# ILL1912
# ITH1805
# FNL2808
# MNI2504
# JAL1207
# FND0811
# RYI2302
# YKT1407
# WMN0105
# TAN1506
# NHS1706
# KAL1409
# RNG0908
# LIZ0202
# INR1012
# EAS0503
# IAE0909
# AND1802
# MER0602
# DDR2704
# MER2407
# MAE0805
# JKN2202
# BNN0703
# KAR0208
# SDL2104
# ZAA3103
# MAR3010
# EHN2109
# ...
